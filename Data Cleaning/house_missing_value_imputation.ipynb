# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

# %%
df=pd.read_csv("house_outlier_treatment.csv")

# %%
df.shape
# Out:
# (20047, 37)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                        0
# society                                           0
# bedrooms                                          0
# baths                                             0
# nearby_locations_and_other_facilities          1822
# rooms                                             0
# link                                              0
# floors                                         6417
# furnished                                      8957
# other_business_and_communication_facilities    7288
# other_community_facilities                     7550
# lawn_or_garden                                 6282
# other_healthcare_and_recreation_facilities     8169
# price                                             0
# area                                              0
# area_sqft                                         0
# servant_quarters                               7572
# kitchens                                       3186
# store_rooms                                    7002
# total_rooms                                    7163
# price_per_sqft                                    0
# drawing_room                                      0
# dining_room                                       0
# lounge_or_sitting_room                            0
# laundry_room                                      0
# study_room                                        0
# prayer_room                                       0
# powder_room                                       0
# gym                                               0
# steam_room                                        0
# servant_quarters_flag                             0
# store_rooms_flag                                  0
# kitchens_flag                                     0
# other_rooms                                       0
# luxury_score                                      0
# furnishing_score                                  0
# agePossession                                     0
# dtype: int64

# %%
df = df.drop(columns=["Unnamed: 0"], errors="ignore")

# %%
df["bedrooms"].isnull().sum()
# Out:
# np.int64(0)

# %%
df['nearby_locations_and_other_facilities'].value_counts()
# Out:
# nearby_locations_and_other_facilities
# Nearby Schools, Nearby Hospitals, Nearby Shopping Malls, Nearby Restaurants, Distance From Airport (kms), Nearby Public Transport Service, Other Nearby Places    16276
# Nearby Schools, Nearby Hospitals, Nearby Shopping Malls, Nearby Restaurants, Nearby Public Transport Service, Other Nearby Places                                   581
# Nearby Schools, Nearby Hospitals, Nearby Shopping Malls, Nearby Restaurants, Distance From Airport (kms), Nearby Public Transport Service                           431
# Nearby Schools, Nearby Hospitals, Nearby Shopping Malls, Nearby Restaurants                                                                                         241
# Nearby Schools, Nearby Hospitals, Nearby Shopping Malls, Nearby Restaurants, Nearby Public Transport Service                                                        237
#                                                                                                                                                                   ...
# Nearby Schools, Nearby Shopping Malls, Nearby Restaurants                                                                                                             1
# Nearby Schools, Nearby Restaurants, Nearby Public Transport Service                                                                                                   1
# Nearby Schools, Distance From Airport (kms), Nearby Public Transport Service, Other Nearby Places                                                                     1
# Nearby Schools, Nearby Shopping Malls, Nearby Restaurants, Distance From Airport (kms)                                                                                1
# Distance From Airport (kms), Other Nearby Places                                                                                                                      1
# Name: count, Length: 79, dtype: int64

# %%
df=df.drop(columns='nearby_locations_and_other_facilities')

# %%
df['floors'].value_counts()
# Out:
# floors
# 2.00     11629
# 3.00      1867
# 4.00        57
# 2.50        32
# 1.50        10
# 5.00         6
# 6.00         4
# 12.00        4
# 23.00        3
# 1.25         3
# 14.00        2
# 7.00         2
# 9.00         2
# 28.00        2
# 41.00        1
# 33.00        1
# 0.00         1
# 32.00        1
# 18.00        1
# 26.00        1
# 10.00        1
# Name: count, dtype: int64

# %%
df['floors'].describe()
# Out:
# count    13630.000000
# mean         2.174083
# std          0.839498
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max         41.000000
# Name: floors, dtype: float64

# %%
sns.boxplot(df['floors'])
# Out:
# <Axes: ylabel='floors'>

# %%
df.shape
# Out:
# (20047, 35)

# %%
df.isnull().sum()
# Out:
# society                                           0
# bedrooms                                          0
# baths                                             0
# rooms                                             0
# link                                              0
# floors                                         6417
# furnished                                      8957
# other_business_and_communication_facilities    7288
# other_community_facilities                     7550
# lawn_or_garden                                 6282
# other_healthcare_and_recreation_facilities     8169
# price                                             0
# area                                              0
# area_sqft                                         0
# servant_quarters                               7572
# kitchens                                       3186
# store_rooms                                    7002
# total_rooms                                    7163
# price_per_sqft                                    0
# drawing_room                                      0
# dining_room                                       0
# lounge_or_sitting_room                            0
# laundry_room                                      0
# study_room                                        0
# prayer_room                                       0
# powder_room                                       0
# gym                                               0
# steam_room                                        0
# servant_quarters_flag                             0
# store_rooms_flag                                  0
# kitchens_flag                                     0
# other_rooms                                       0
# luxury_score                                      0
# furnishing_score                                  0
# agePossession                                     0
# dtype: int64

# %%
df['floors'].describe()
# Out:
# count    13630.000000
# mean         2.174083
# std          0.839498
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max         41.000000
# Name: floors, dtype: float64

# %%
df = df[(df['floors'] <= 10) | (df['floors'].isna())]

# %%
df.shape
# Out:
# (20031, 35)

# %%
df['floors'].describe()
# Out:
# count    13614.000000
# mean         2.150856
# std          0.395687
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max         10.000000
# Name: floors, dtype: float64

# %%
df['floors'].fillna(2, inplace=True)
# Out:
# C:\Users\zeeshan_ahmed\AppData\Local\Temp\ipykernel_21260\232183975.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['floors'].fillna(2, inplace=True)
# C:\Users\zeeshan_ahmed\AppData\Local\Temp\ipykernel_21260\232183975.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['floors'].fillna(2, inplace=True)

# %%
df.isnull().sum()
# Out:
# society                                           0
# bedrooms                                          0
# baths                                             0
# rooms                                             0
# link                                              0
# floors                                            0
# furnished                                      8955
# other_business_and_communication_facilities    7282
# other_community_facilities                     7545
# lawn_or_garden                                 6279
# other_healthcare_and_recreation_facilities     8163
# price                                             0
# area                                              0
# area_sqft                                         0
# servant_quarters                               7567
# kitchens                                       3183
# store_rooms                                    6995
# total_rooms                                    7156
# price_per_sqft                                    0
# drawing_room                                      0
# dining_room                                       0
# lounge_or_sitting_room                            0
# laundry_room                                      0
# study_room                                        0
# prayer_room                                       0
# powder_room                                       0
# gym                                               0
# steam_room                                        0
# servant_quarters_flag                             0
# store_rooms_flag                                  0
# kitchens_flag                                     0
# other_rooms                                       0
# luxury_score                                      0
# furnishing_score                                  0
# agePossession                                     0
# dtype: int64

# %%
df.drop(columns=[
    'servant_quarters_flag',
    'store_rooms_flag',
    'kitchens_flag'
], inplace=True)
# Out:
# C:\Users\zeeshan_ahmed\AppData\Local\Temp\ipykernel_21260\2319007009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=[

# %%
df.isnull().sum()
# Out:
# society                                           0
# bedrooms                                          0
# baths                                             0
# rooms                                             0
# link                                              0
# floors                                            0
# furnished                                      8955
# other_business_and_communication_facilities    7282
# other_community_facilities                     7545
# lawn_or_garden                                 6279
# other_healthcare_and_recreation_facilities     8163
# price                                             0
# area                                              0
# area_sqft                                         0
# servant_quarters                               7567
# kitchens                                       3183
# store_rooms                                    6995
# total_rooms                                    7156
# price_per_sqft                                    0
# drawing_room                                      0
# dining_room                                       0
# lounge_or_sitting_room                            0
# laundry_room                                      0
# study_room                                        0
# prayer_room                                       0
# powder_room                                       0
# gym                                               0
# steam_room                                        0
# other_rooms                                       0
# luxury_score                                      0
# furnishing_score                                  0
# agePossession                                     0
# dtype: int64

# %%
df['lawn_or_garden'].value_counts()
# Out:
# lawn_or_garden
# True    13752
# Name: count, dtype: int64

# %%
df['lawn_or_garden'] = df['lawn_or_garden'].fillna(False).astype(int)
# Out:
# C:\Users\zeeshan_ahmed\AppData\Local\Temp\ipykernel_21260\4154945183.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['lawn_or_garden'] = df['lawn_or_garden'].fillna(False).astype(int)
# C:\Users\zeeshan_ahmed\AppData\Local\Temp\ipykernel_21260\4154945183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lawn_or_garden'] = df['lawn_or_garden'].fillna(False).astype(int)

# %%
df.drop(columns=[
    'other_business_and_communication_facilities',
    'other_community_facilities',
    'other_healthcare_and_recreation_facilities'
], inplace=True)
# Out:
# C:\Users\zeeshan_ahmed\AppData\Local\Temp\ipykernel_21260\4199650522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=[

# %%
df.columns
# Out:
# Index(['society', 'bedrooms', 'baths', 'rooms', 'link', 'floors', 'furnished',
#        'lawn_or_garden', 'price', 'area', 'area_sqft', 'servant_quarters',
#        'kitchens', 'store_rooms', 'total_rooms', 'price_per_sqft',
#        'drawing_room', 'dining_room', 'lounge_or_sitting_room', 'laundry_room',
#        'study_room', 'prayer_room', 'powder_room', 'gym', 'steam_room',
#        'other_rooms', 'luxury_score', 'furnishing_score', 'agePossession'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# society                      0
# bedrooms                     0
# baths                        0
# rooms                        0
# link                         0
# floors                       0
# furnished                 8955
# lawn_or_garden               0
# price                        0
# area                         0
# area_sqft                    0
# servant_quarters          7567
# kitchens                  3183
# store_rooms               6995
# price_per_sqft               0
# drawing_room                 0
# dining_room                  0
# lounge_or_sitting_room       0
# laundry_room                 0
# study_room                   0
# prayer_room                  0
# powder_room                  0
# gym                          0
# steam_room                   0
# other_rooms                  0
# luxury_score                 0
# furnishing_score             0
# agePossession                0
# dtype: int64

# %%
df=df.drop(columns='total_rooms')

# %%
df['furnished'].describe()
# Out:
# count     11076
# unique        1
# top        True
# freq      11076
# Name: furnished, dtype: object
